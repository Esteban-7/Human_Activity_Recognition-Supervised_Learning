# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
 df = pd.read_csv('data/train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
df.shape
# Out:
# (7352, 563)

# %%
df.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
df = df.drop("subject", axis = 1)

# %%
df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.923527         -0.934724  ...                        -0.298676
# 1         -0.957686         -0.943068  ...                        -0.595051
# 2         -0.977469         -0.938692  ...                        -0.390748
# 3         -0.989302         -0.938692  ...                        -0.117290
# 4         -0.990441         -0.942469  ...                        -0.351471
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.710304                    -0.112754
# 1                        -0.861499                     0.053477
# 2                        -0.760104                    -0.118559
# 3                        -0.482845                    -0.036788
# 4                        -0.699205                     0.123320
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.030400                         -0.464761
# 1                             -0.007435                         -0.732626
# 2                              0.177899                          0.100699
# 3                             -0.012892                          0.640011
# 4                              0.122542                          0.693578
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.018446             -0.841247
# 1                              0.703511             -0.844788
# 2                              0.808529             -0.848933
# 3                             -0.485366             -0.848649
# 4                             -0.615971             -0.847865
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  Activity
# 0              0.179941             -0.058627  STANDING
# 1              0.180289             -0.054317  STANDING
# 2              0.180637             -0.049118  STANDING
# 3              0.181935             -0.047663  STANDING
# 4              0.185151             -0.043892  STANDING
#
# [5 rows x 562 columns]

# %%
df.dtypes
# Out:
# tBodyAcc-mean()-X                       float64
# tBodyAcc-mean()-Y                       float64
# tBodyAcc-mean()-Z                       float64
# tBodyAcc-std()-X                        float64
# tBodyAcc-std()-Y                        float64
#                                          ...
# angle(tBodyGyroJerkMean,gravityMean)    float64
# angle(X,gravityMean)                    float64
# angle(Y,gravityMean)                    float64
# angle(Z,gravityMean)                    float64
# Activity                                 object
# Length: 562, dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    561
# object       1
# dtype: int64

# %%
stats = df.iloc[:,:-1].describe()
stats #create a dataframe that holds the statistical description
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# 25%           -0.992754         -0.978129         -0.980233         -0.993591
# 50%           -0.946196         -0.851897         -0.859365         -0.950709
# 75%           -0.242813         -0.034231         -0.262415         -0.292680
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       7352.000000       7352.000000       7352.000000  ...
# mean          -0.526907         -0.606150         -0.468604  ...
# std            0.485942          0.414122          0.544547  ...
# min           -1.000000         -1.000000         -1.000000  ...
# 25%           -0.978162         -0.980251         -0.936219  ...
# 50%           -0.857328         -0.857143         -0.881637  ...
# 75%           -0.066701         -0.265671         -0.017129  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# count                      7352.000000                      7352.000000
# mean                          0.125293                        -0.307009
# std                           0.250994                         0.321011
# min                          -1.000000                        -0.995357
# 25%                          -0.023692                        -0.542602
# 50%                           0.134000                        -0.343685
# 75%                           0.289096                        -0.126979
# max                           0.946700                         0.989538
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      7352.000000                  7352.000000
# mean                         -0.625294                     0.008684
# std                           0.307584                     0.336787
# min                          -0.999765                    -0.976580
# 25%                          -0.845573                    -0.121527
# 50%                          -0.711692                     0.009509
# 75%                          -0.503878                     0.150865
# max                           0.956845                     1.000000
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           7352.000000                       7352.000000
# mean                               0.002186                          0.008726
# std                                0.448306                          0.608303
# min                               -1.000000                         -1.000000
# 25%                               -0.289549                         -0.482273
# 50%                                0.008943                          0.008735
# 75%                                0.292861                          0.506187
# max                                1.000000                          0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           7352.000000           7352.000000
# mean                              -0.005981             -0.489547
# std                                0.477975              0.511807
# min                               -1.000000             -1.000000
# 25%                               -0.376341             -0.812065
# 50%                               -0.000368             -0.709417
# 75%                                0.359368             -0.509079
# max                                0.996078              1.000000
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)
# count           7352.000000           7352.000000
# mean               0.058593             -0.056515
# std                0.297480              0.279122
# min               -1.000000             -1.000000
# 25%               -0.017885             -0.143414
# 50%                0.182071              0.003181
# 75%                0.248353              0.107659
# max                0.478157              1.000000
#
# [8 rows x 561 columns]

# %%
mins = stats.min(axis=1)
maxs = stats.max(axis=1)
print('Minimum value in each row : ')
print(mins)
print('\nMaximum value in each row : ')
print(maxs)
# Out:
# Minimum value in each row :
# count    7352.000000
# mean       -0.984059
# std         0.040811
# min        -1.000000
# 25%        -1.000000
# 50%        -1.000000
# 75%        -0.991362
# max         0.465197
# dtype: float64
#
# Maximum value in each row :
# count    7352.000000
# mean        0.830434
# std         0.751733
# min        -0.493874
# 25%         0.804863
# 50%         0.963906
# 75%         0.994417
# max         1.000000
# dtype: float64

# %% [markdown]
# We can see that all values are bounded in between -1 and 1. Meaning that the data can be thought of a multidimentional sphere of redius 1.

# %%
print(df.isnull().sum())
print(f"\nThe total number of null observations across the data set is: {sum(list(df.isnull().sum()))}")
# Out:
# tBodyAcc-mean()-X                       0
# tBodyAcc-mean()-Y                       0
# tBodyAcc-mean()-Z                       0
# tBodyAcc-std()-X                        0
# tBodyAcc-std()-Y                        0
#                                        ..
# angle(tBodyGyroJerkMean,gravityMean)    0
# angle(X,gravityMean)                    0
# angle(Y,gravityMean)                    0
# angle(Z,gravityMean)                    0
# Activity                                0
# Length: 562, dtype: int64
#
# The total number of null observations across the data set is: 0

# %%
print(df.isna().sum())
print(f"\nThe total number of NA observations across the data set is: {sum(list(df.isna().sum()))}")
# Out:
# tBodyAcc-mean()-X                       0
# tBodyAcc-mean()-Y                       0
# tBodyAcc-mean()-Z                       0
# tBodyAcc-std()-X                        0
# tBodyAcc-std()-Y                        0
#                                        ..
# angle(tBodyGyroJerkMean,gravityMean)    0
# angle(X,gravityMean)                    0
# angle(Y,gravityMean)                    0
# angle(Z,gravityMean)                    0
# Activity                                0
# Length: 562, dtype: int64
#
# The total number of NA observations across the data set is: 0

# %% [markdown]
# A new variable will be created to transform the categorical values of the target into numeric ones:

# %%
print("Value counts for the target variable:")
print(df['Activity'].value_counts())
df['Activity'].value_counts().plot(kind='bar')
# Out:
# Value counts for the target variable:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64
# <AxesSubplot:>

# %%
df['activity_num'] = df['Activity']
df['activity_num'].replace(['STANDING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS', 'SITTING','LAYING', 'WALKING'],
                        [1,2,3,4,5,6], inplace=True)
df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  Activity  \
# 0             -0.841247              0.179941             -0.058627  STANDING
# 1             -0.844788              0.180289             -0.054317  STANDING
# 2             -0.848933              0.180637             -0.049118  STANDING
# 3             -0.848649              0.181935             -0.047663  STANDING
# 4             -0.847865              0.185151             -0.043892  STANDING
#
#    activity_num
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#
# [5 rows x 563 columns]

# %%
correlation = df.drop("Activity", axis = 1).corr()
correlation.head()
# Out:
#                    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# tBodyAcc-mean()-X           1.000000           0.148061          -0.256952
# tBodyAcc-mean()-Y           0.148061           1.000000          -0.078769
# tBodyAcc-mean()-Z          -0.256952          -0.078769           1.000000
# tBodyAcc-std()-X            0.000619          -0.045160          -0.020217
# tBodyAcc-std()-Y           -0.021903          -0.044920          -0.016641
#
#                    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# tBodyAcc-mean()-X          0.000619         -0.021903         -0.044617
# tBodyAcc-mean()-Y         -0.045160         -0.044920         -0.049746
# tBodyAcc-mean()-Z         -0.020217         -0.016641         -0.008410
# tBodyAcc-std()-X           1.000000          0.927461          0.851668
# tBodyAcc-std()-Y           0.927461          1.000000          0.895510
#
#                    tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  \
# tBodyAcc-mean()-X          0.006290         -0.022754         -0.047558
# tBodyAcc-mean()-Y         -0.044180         -0.045049         -0.050402
# tBodyAcc-mean()-Z         -0.018747         -0.015203         -0.001988
# tBodyAcc-std()-X           0.998632          0.920888          0.846392
# tBodyAcc-std()-Y           0.922803          0.997347          0.894509
#
#                    tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# tBodyAcc-mean()-X          0.044062  ...                        -0.017557
# tBodyAcc-mean()-Y         -0.038108  ...                        -0.001587
# tBodyAcc-mean()-Z         -0.037197  ...                         0.020091
# tBodyAcc-std()-X           0.980844  ...                         0.148034
# tBodyAcc-std()-Y           0.917366  ...                         0.206227
#
#                    fBodyBodyGyroJerkMag-kurtosis()  \
# tBodyAcc-mean()-X                        -0.015613
# tBodyAcc-mean()-Y                        -0.004459
# tBodyAcc-mean()-Z                         0.019127
# tBodyAcc-std()-X                          0.115565
# tBodyAcc-std()-Y                          0.176946
#
#                    angle(tBodyAccMean,gravity)  \
# tBodyAcc-mean()-X                    -0.544320
# tBodyAcc-mean()-Y                     0.070559
# tBodyAcc-mean()-Z                     0.052841
# tBodyAcc-std()-X                     -0.035011
# tBodyAcc-std()-Y                     -0.020379
#
#                    angle(tBodyAccJerkMean),gravityMean)  \
# tBodyAcc-mean()-X                              0.012173
# tBodyAcc-mean()-Y                             -0.013541
# tBodyAcc-mean()-Z                             -0.039836
# tBodyAcc-std()-X                              -0.021633
# tBodyAcc-std()-Y                              -0.012505
#
#                    angle(tBodyGyroMean,gravityMean)  \
# tBodyAcc-mean()-X                          0.037444
# tBodyAcc-mean()-Y                          0.017967
# tBodyAcc-mean()-Z                         -0.063609
# tBodyAcc-std()-X                           0.018985
# tBodyAcc-std()-Y                          -0.008507
#
#                    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# tBodyAcc-mean()-X                              0.028844             -0.035257
# tBodyAcc-mean()-Y                              0.075679             -0.005309
# tBodyAcc-mean()-Z                             -0.034037              0.008587
# tBodyAcc-std()-X                              -0.024810             -0.371653
# tBodyAcc-std()-Y                              -0.014592             -0.380531
#
#                    angle(Y,gravityMean)  angle(Z,gravityMean)  activity_num
# tBodyAcc-mean()-X              0.034371              0.028242     -0.010490
# tBodyAcc-mean()-Y              0.001053             -0.013903      0.019733
# tBodyAcc-mean()-Z             -0.015288             -0.022643      0.023283
# tBodyAcc-std()-X               0.471065              0.394825      0.039275
# tBodyAcc-std()-Y               0.523600              0.433169      0.105048
#
# [5 rows x 562 columns]

# %%
import matplotlib.pyplot as plt

correlation = correlation.to_numpy()

f = plt.figure(figsize=(20, 17))
plt.matshow(correlation, fignum=f.number,cmap='magma')
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Correlation Matrix', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # PCA

# %%
from sklearn import decomposition

x = df.drop(["Activity","activity_num"], axis = 1)

pca = decomposition.PCA()
pca.fit(x)
principal_components = pca.transform(x)
df_pca = pd.DataFrame(principal_components)
df_pca.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -5.520280 -0.290278 -1.529929  1.333242  1.425089 -0.194708  0.577454
# 1 -5.535350 -0.082530 -1.924804  0.671273  0.671260  0.735144 -0.616908
# 2 -5.474988  0.287387 -2.144642  0.531806  0.207824 -0.037772  0.057628
# 3 -5.677232  0.897031 -2.018220  0.157125  0.759085  1.079547 -0.267805
# 4 -5.748749  1.162952 -2.139533  0.207823  0.473090  0.463035 -0.152227
#
#         7         8         9    ...           551           552  \
# 0  0.691490 -1.222865 -0.363414  ... -6.922643e-19 -1.700183e-16
# 1 -0.771714 -0.615496 -0.895525  ... -1.439789e-17 -6.865424e-18
# 2  0.093917 -0.063147 -0.216898  ... -4.111373e-18  4.717459e-17
# 3 -0.731391  0.281296  0.466269  ... -1.661319e-16  6.553197e-18
# 4 -0.107509  0.289819  0.539206  ... -5.199952e-17  2.089456e-17
#
#             553           554           555           556           557  \
# 0 -2.218851e-16  1.412575e-16  4.116624e-17 -1.084985e-16  1.016770e-15
# 1 -2.583876e-16  2.069710e-17  4.682698e-17 -5.366981e-16 -3.527862e-16
# 2 -1.515091e-16  6.485891e-18  4.048619e-17 -9.089547e-18  8.140425e-16
# 3 -1.747703e-16  3.465223e-17  6.703025e-18  9.641519e-17 -2.983557e-16
# 4 -1.858470e-16  3.160710e-17 -1.291358e-16 -9.145193e-17 -2.937485e-16
#
#             558           559           560
# 0  1.035027e-16 -7.845644e-17 -2.244708e-16
# 1  1.061070e-16  1.242805e-16 -1.441219e-16
# 2 -5.076688e-19  5.502098e-17 -1.188501e-16
# 3 -3.199072e-16 -1.140142e-16 -6.524859e-17
# 4  4.384183e-16  9.111358e-17 -1.584097e-16
#
# [5 rows x 561 columns]

# %%
variance = 0
component = 0
for i in pca.explained_variance_ratio_:
    variance = variance + i
    component = component + 1
    if variance > 0.90:
        print(component)
        break
# Out:
# 34

# %%
PC = range(1, 35)

f = plt.figure(figsize=(20, 8))
plt.bar(PC,pca.explained_variance_ratio_[:34]*100, color = 'lightblue')
plt.xlabel('Principal Components')
plt.ylabel('Variance % ')
plt.xticks(PC)
plt.show()

# %% [markdown]
# ## so by using pca the dimensions will be reduced from more than 500 to 34 principal components to make the computing faster

# %%
x_train = df_pca.iloc[:, 0:34]
y_train = df[["activity_num"]]

# %%
df_test = pd.read_csv('data/test.csv')

# %%
df_test['activity_num'] = df_test['Activity']
df_test['activity_num'].replace(['STANDING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS', 'SITTING','LAYING', 'WALKING'],
                        [1,2,3,4,5,6], inplace=True)

# %%
x_test = pca.transform(df_test.drop(["Activity","activity_num"], axis = 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-012ba42de434> in <module>
# ----> 1 x_test = pca.transform(df_test.drop(["Activity","activity_num"], axis = 1))
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_base.py in transform(self, X)
#     124         check_is_fitted(self)
#     125
# --> 126         X = self._validate_data(X, dtype=[np.float64, np.float32], reset=False)
#     127         if self.mean_ is not None:
#     128             X = X - self.mean_
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     435
#     436         if check_params.get('ensure_2d', True):
# --> 437             self._check_n_features(X, reset=reset)
#     438
#     439         return out
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _check_n_features(self, X, reset)
#     363
#     364         if n_features != self.n_features_in_:
# --> 365             raise ValueError(
#     366                 f"X has {n_features} features, but {self.__class__.__name__} "
#     367                 f"is expecting {self.n_features_in_} features as input.")
#
# ValueError: X has 562 features, but PCA is expecting 561 features as input.
